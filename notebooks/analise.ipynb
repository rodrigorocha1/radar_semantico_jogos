# %%
import pandas as pd

# %%
dataframe_original = pd.read_pickle('../dataframe_completo.pkl')
dataframe_original
# Out:
#                         id_texto  codigo_steam   nome_jogo  \
# 0                      218261480      105600.0    terraria
# 1                      218139992      105600.0    terraria
# 2                      218042630      105600.0    terraria
# 3                      218041328      105600.0    terraria
# 4                      218038914      105600.0    terraria
# ...                          ...           ...         ...
# 1795  Ugxgz04qQk-ChCNgkBl4AaABAg           NaN  subnautica
# 1796  UgzWYIMYiSx7blrswdp4AaABAg           NaN  subnautica
# 1797  UgxyfwvXpJCs-V_Q8ed4AaABAg           NaN  subnautica
# 1798  UgzMWUotbK_fN3Taf1R4AaABAg           NaN  subnautica
# 1799  UgwaThRn6SAoF6guCw54AaABAg           NaN  subnautica
#
#                                        texto_comentario     site
# 0                                             E POGGERS    steam
# 1                                                    oi    steam
# ...

# %%
dataframe_original[dataframe_original['nome_jogo'] == 'no_mans_sky']
# Out:
#                         id_texto  codigo_steam    nome_jogo  \
# 2015                   218106214      275850.0  no_mans_sky
# 2016                   217998527      275850.0  no_mans_sky
# 2017                   217281471      275850.0  no_mans_sky
# 2018                   216968351      275850.0  no_mans_sky
# 2019                   216245967      275850.0  no_mans_sky
# ...                          ...           ...          ...
# 487   UgyyBl95OeNLiMoupXt4AaABAg      275850.0  no_mans_sky
# 488   UgzKOVAV73evMsjMjvt4AaABAg      275850.0  no_mans_sky
# 489   Ugx0btxx5AFTkPGn5rV4AaABAg      275850.0  no_mans_sky
# 490   UgwoD35AFQqPSUyVu214AaABAg      275850.0  no_mans_sky
# 491   UgyfYJTCgU1SKpXZkCZ4AaABAg      275850.0  no_mans_sky
#
#                                        texto_comentario     site
# 2015                            O melhor jogo do estilo    steam
# 2016  O jogo está incrivel, sem palavras, parabens H...    steam
# ...

# %%
dataframe_original['nome_jogo'].value_counts()
# Out:
# nome_jogo
# subnautica                                  1335
# no_mans_sky                                  644
# star_rupture                                 631
# factorio                                     357
# satisfactory                                 340
#                                             ...
# x4_timelines                                   1
# stellaris_rick_the_cube_species_portrait       1
# the_planet_crafter_planet_humble               1
# surviving_mars                                 1
# x4_hyperion_pack                               1
# Name: count, Length: 61, dtype: int64

# %%
dataframe_original.dtypes
# Out:
# id_texto                str
# codigo_steam        float64
# nome_jogo               str
# texto_comentario        str
# site                    str
# dtype: object
